# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nethan Binu**
# Student

# %% [markdown]
# *Iam interested in data science because , I love anlaysis of data. I would like to create data models and data visualizations*

# %% [markdown]
# ### My code in the next cell will multiply two numbers

# %%
def multiply (a,b):
    return "product is: ", a*b
multiply(10,12)
# Out:
# ('product is: ', 120)

# %% [markdown]
# Sentence above horizontal rule
# ***
# Sentence below horizontal rule
#
# following is a numbered list
#
# 1. list 1
# 2. List 2
# 3. List 3
#
#
# following is a bulleted list
#
# - bullet 1
# - bullet 2
# - bullet 3
#
# ~~~ strikethrough example ~~~
#
# [google](https://www.google.com/)
#
#
# Following is an image
# ![Yosemite.jpg](attachment:Yosemite.jpg)
